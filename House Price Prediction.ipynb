# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data= pd.read_csv('ParisHousing.csv')
data
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %% [raw]
# All attributes are numeric variables and they are listed bellow:
#
# squareMeters
# numberOfRooms
# hasYard
# hasPool
# floors - number of floors
# cityCode - zip code
# cityPartRange - the higher the range, the more exclusive the neighbourhood is
# numPrevOwners - number of prevoious owners
# made - year
# isNewBuilt
# hasStormProtector
# basement - basement square meters
# attic - attic square meteres
# garage - garage size
# hasStorageRoom
# hasGuestRoom - number of guest rooms
# price - predicted value

# %% [markdown]
# # Exploratory data analysis

# %%
data.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made    isNewBuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
#Checking their is any null value or not
data.isnull().sum()
# Out:
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       10000 non-null  int64
#  1   numberOfRooms      10000 non-null  int64
#  2   hasYard            10000 non-null  int64
#  3   hasPool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   cityCode           10000 non-null  int64
#  6   cityPartRange      10000 non-null  int64
#  7   numPrevOwners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isNewBuilt         10000 non-null  int64
#  10  hasStormProtector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasStorageRoom     10000 non-null  int64
#  15  hasGuestRoom       10000 non-null  int64
# ...

# %%
data.corr()
# Out:
#                    squareMeters  numberOfRooms   hasYard   hasPool    floors  \
# squareMeters           1.000000       0.009573 -0.006650 -0.005594  0.001109
# numberOfRooms          0.009573       1.000000 -0.011240  0.017015  0.022244
# hasYard               -0.006650      -0.011240  1.000000  0.015514 -0.000883
# hasPool               -0.005594       0.017015  0.015514  1.000000 -0.004006
# floors                 0.001109       0.022244 -0.000883 -0.004006  1.000000
# cityCode              -0.001541       0.009040  0.006760  0.008072  0.002207
# cityPartRange          0.008758       0.008340  0.005023  0.014613 -0.004921
# numPrevOwners          0.016619       0.016766  0.004279 -0.006848  0.002463
# made                  -0.007207       0.003978  0.002214  0.001894  0.005022
# isNewBuilt            -0.010667      -0.002865 -0.008370  0.000188  0.002458
# hasStormProtector      0.007480      -0.001656 -0.007598 -0.001001 -0.008566
# ...

# %%
# To find out their is any outliers in the attribute
plt.figure(figsize=(10,4))
sns.boxplot(data.iloc[:,:-1])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Train- test split

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values
print(x.shape)
print(y.shape)
# Out:
# (10000, 16)
# (10000,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
x_trans= scalar.fit_transform(x_train)
print(x_trans.shape)
print(y_train.shape)
# Out:
# (7000, 16)
# (7000,)

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(x_trans, y_train)
# Out:
# LinearRegression()

# %%
#Creating a pipeline for first model
from sklearn.pipeline import make_pipeline
pipe1= make_pipeline(scalar, model1)

# %%
pipe1.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
pred1 = pipe1.predict(x_test)

# %%
pred1
# Out:
# array([7962604.24888725, 3715858.52278415, 8553855.41160022, ...,
#        5220203.92605014, 5864616.84327634, 4829125.46774529])

# %% [markdown]
# ### # Cheking the accuracy of Multiple Regression model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae1 = mean_absolute_error(y_test, pred1)
msa1 = mean_squared_error(y_test, pred1)

# %%
print(mae1)
print(msa1)
# Out:
# 1485.2080395502478
# 3605360.3566407845

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, pred1))
# Out:
# 0.9999995771430428

# %%
residual = y_test- pred1

# %%
#Residual plot
#Residual plot follows normal distribution i.e. model is perfectly fitted  
sns.displot(residual)

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
model2 = Ridge()
model2.fit(x_trans, y_train)
# Out:
# Ridge()

# %%
#Creating a pipeline for second model
from sklearn.pipeline import make_pipeline
pipe2 = make_pipeline(scalar, model2)

# %%
pipe2.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
pred2= pipe2.predict(x_test)

# %% [markdown]
# ### # Cheking the accuracy of Ridge Regression model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae1 = mean_absolute_error(y_test, pred2)
msa1 = mean_squared_error(y_test, pred2)

# %%
print(mae1)
print(msa1)
# Out:
# 1532.211981369912
# 3798283.3278248124

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, pred2))
# Out:
# 0.9999995545159508

# %%
residual = y_test- pred2

# %%
# Residual plot
#Residual plot follows normal distribution i.e. model is perfectly fitted 
sns.displot(residual)

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
model3 = Lasso()
model3.fit(x_train, y_train)
# Out:
# Lasso()

# %%
#Creating a pipeline for first model
from sklearn.pipeline import make_pipeline
pipe3= make_pipeline(scalar, model3)

# %%
pipe3.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
pred3= pipe3.predict(x_test)

# %%
residual= y_test- pred3

# %%
#Residual plot
#Residual plot follows normal distribution i.e. model is perfectly fitted 
sns.displot(residual)

# %% [markdown]
# ### # Cheking the accuracy of Lasso Regression model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae3 = mean_absolute_error(y_test, pred3)
msa3 = mean_squared_error(y_test, pred3)

# %%
print(mae3)
print(msa3)
# Out:
# 1485.1506231962553
# 3605266.2481277823

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, pred3))
# Out:
# 0.9999995771540804

# %%
# All three model are fitted good. but Lasso regression gives more accuracy. 
print("No Regularization:", r2_score(y_test, pred1))
print("Ridge:", r2_score(y_test, pred2))
print("Lasso:", r2_score(y_test, pred3))
# Out:
# No Regularization: 0.9999995771430428
# Ridge: 0.9999995545159508
# Lasso: 0.9999995771540804

# %%
# Save the model
import pickle

# %%
pickle.dump(pipe3, open('Regression_model.pkl','wb'))
